# %%
import matplotlib.pyplot as plt
import pickle

# %%
# %matplotlib notebook

# %%
with open('d:/moje_dokumenty/Desktop/diplomka/model/text parts/tables/trial_objects/lala.pickle','rb') as fid:
    fig = pickle.load(fid)

# %%
fig.suptitle("tralala")
# Out:
# Text(0.5, 0.98, 'tralala')

# %%
fig.axes[0].set_title("la")
# Out:
# Text(0.5, 1.0, 'la')

# %%
fig

# %%
fig.savefig('d:/moje_dokumenty/Desktop/diplomka/model/text parts/tables/trial_objects/lala.png')
