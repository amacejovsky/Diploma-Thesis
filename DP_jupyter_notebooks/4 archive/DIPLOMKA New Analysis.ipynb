# %% [markdown]
# # New analysis

# %% [markdown]
# for simulations with 0 trade costs or importing transport firms

# %%
from model_tools import TS, Special_TS
from model_tools import load_data, load_hdf
from model_tools import Visual 
from model_tools import cut, cut_dict

# %%
plot = Visual.plot
curve = Visual.curve
whiskers = Visual.whiskers
histogram = Visual.histogram
compare = Visual.compare
panel = Visual.panel

# %%
# %cd "d:\moje_dokumenty\Desktop\diplomka\model\data\hdf_new"
# Out:
# d:\moje_dokumenty\Desktop\diplomka\model\data\hdf_new

# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %%
panels = ("main", "sentiments", "int_trade", "yearly", "money", "labor", "profits",  "industry", "cons", "cycles")

# %%
pans = {ind: pan for ind, pan in enumerate(panels)}

# %% [markdown]
# # almost perfect union
#
# 0 trade costs, pegged exchange rates, baseline wages

# %%
# %cd "d:\moje_dokumenty\Desktop\diplomka\model\data\hdf"
# Out:
# d:\moje_dokumenty\Desktop\diplomka\model\data\hdf

# %% [markdown]
# quotas = [0.01, 0.03, 0.05, 0.1, 0.3, 0.5, 0.75, 1]

# %%
for s in range(1,9):
    path = '2*perfect_union_' + str(s) + '.h5'
    exec("union_BB_data_" + str(s)+ ", union_BB_files_" + str(s)+ ", union_BB_pars_" + str(s)+
         " = load_hdf(path, condition = None,  ret_parameters = True)" )

# %%
for s in range(9,17):
    path = '2*perfect_union_' + str(s) + '.h5'
    exec("union_BS_data_" + str(s-8)+ ", union_BS_files_" + str(s-8)+ ", union_BS_pars_" + str(s-8)+
         " = load_hdf(path, condition = None,  ret_parameters = True)" )

# %%
j = 0

# %%
j += 1
j
# Out:
# 1

# %%
i = 0

# %%
i += 1
i
# Out:
# 3

# %%
panel(*union_BS_data_15, name = panels[j])

# %% [markdown]
# # 0 trade costs

# %% [markdown]
# 0 trade costs, free market, standard wage experiments in country 1 or both

# %%
# %cd "d:\moje_dokumenty\Desktop\diplomka\model\data\hdf_new"
# Out:
# d:\moje_dokumenty\Desktop\diplomka\model\data\hdf_new

# %%
for s in range(1,5):
    path = '2*new_2C_' + str(s) + '.h5'
    exec("new_2C_BB_data_" + str(s)+ ", new_2C_BB_files_" + str(s)+ ", new_2C_BB_pars_" + str(s)+
         " = load_hdf(path, condition = None,  ret_parameters = True)" )

# %%
for s in range(5,9):
    path = '2*new_2C_' + str(s) + '.h5'
    exec("new_2C_BS_data_" + str(s-8)+ ", new_2C_BS_files_" + str(s-8)+ ", new_2C_BS_pars_" + str(s-8)+
         " = load_hdf(path, condition = None,  ret_parameters = True)" )

# %%
new_2C_BB_extr_data, new_2C_BB_extr_files, new_2C_BB_extr_pars = load_hdf('2*new_BB_extr.h5', condition = None,  ret_parameters = True)
new_2C_BS_extr_data, new_2C_BS_extr_files, new_2C_BS_extr_pars = load_hdf('2*new_BS_extr.h5', condition = None,  ret_parameters = True)

# %%
j = 0

# %%
j += 1
j
# Out:
# 3

# %%
i = 0

# %%
i += 1
i
# Out:
# 3

# %%
panel(*new_2C_BS_data_8, name = panels[j])

# %%
panel(*new_2C_BS_extr_data, name = panels[j])
